# %%
import nltk

def sen_seg(data): 
    sens = []
    to_replace = ['et al. ', 'Fig. ', 'e.g. ', 'i.e. ', 'Ref. ', 'Figs. ', ' ca. ', 'approx. ', '(ca. ', 'etc.) ']
    for tr in to_replace:
        data = data.replace(tr, tr[:-2]+'####@')
    tmp = nltk.sent_tokenize(data)
    # tmp = data.split('. ')
    for i, t in enumerate(tmp):
        for tr in to_replace:
            t = t.replace(tr[:-2]+'####@', tr)
        tmp[i] = t
    for t in tmp:
        split_t = nltk.word_tokenize(t)
        if 10<len(split_t)<90:
            sens.append(split_t)
    return sens

# %%
import kashgari
from kashgari.tasks.classification import CNN_Attention_Model, CNN_Model

load_CNN = CNN_Model.load_model('CNN_94_95_93')
load_CNN_Attention = CNN_Attention_Model.load_model('CNN_Attention_91')
# Out:
# 2022-08-29 14:23:03,001 [DEBUG] kashgari - ------------------------------------------------
# 2022-08-29 14:23:03,004 [DEBUG] kashgari - Loaded gensim word2vec model's vocab
# 2022-08-29 14:23:03,004 [DEBUG] kashgari - model        : mat_embedding3/vectors.txt
# 2022-08-29 14:23:03,005 [DEBUG] kashgari - word count   : 529690
# 2022-08-29 14:23:03,005 [DEBUG] kashgari - Top 50 words : ['the', 'of', '.', ',', 'and', '<nUm>', 'in', 'a', 'to', ')', '(', 'with', '-', 'for', 'is', 'by', 'on', 'was', 'at', 'were', 'that', '–', 'as', 'are', 'from', '/', 'an', 'temperature', 'surface', 'using', 'high', 'which', 'C', '°', 'this', '%', 'In', 'it', 'A', '=', 'structure', 'properties', ':', 'phase', 'results', 'effect', 'these', 'than', 'based', 'different']
# 2022-08-29 14:23:03,005 [DEBUG] kashgari - ------------------------------------------------
# 2022-08-29 14:24:46,446 [DEBUG] kashgari - ------------------------------------------------
# 2022-08-29 14:24:46,448 [DEBUG] kashgari - Loaded gensim word2vec model's vocab
# 2022-08-29 14:24:46,448 [DEBUG] kashgari - model        : mat_embedding3/vectors.txt
# 2022-08-29 14:24:46,448 [DEBUG] kashgari - word count   : 529690
# 2022-08-29 14:24:46,449 [DEBUG] kashgari - Top 50 words : ['the', 'of', '.', ',', 'and', '<nUm>', 'in', 'a', 'to', ')', '(', 'with', '-', 'for', 'is', 'by', 'on', 'was', 'at', 'were', 'that', '–', 'as', 'are', 'from', '/', 'an', 'temperature', 'surface', 'using', 'high', 'which', 'C', '°', 'this', '%', 'In', 'it', 'A', '=', 'structure', 'properties', ':', 'phase', 'results', 'effect', 'these', 'than', 'based', 'different']
# 2022-08-29 14:24:46,450 [DEBUG] kashgari - ------------------------------------------------

# %%
import json

with open('total_doi_year.json', 'r', encoding='utf-8') as f:
    doi_year = json.load(f)

# %%
def get_opinions(sens):
    if sens == []:
        return [], []
    find_opinion = []
    result = load_CNN.predict(sens)
    for i, tx in enumerate(sens):
        if result[i] == 'opinion':
            find_opinion.append(tx)
    if find_opinion == []:
        return [], []
    find_opps = []
    find_chas = []
    result = load_CNN_Attention.predict(find_opinion)
    for i, tx in enumerate(find_opinion):
        if result[i] == 'driver':
            find_opps.append(' '.join(tx))
        else:
            find_chas.append(' '.join(tx))
    return find_opps, find_chas

# %%
def ALD_justify(text):
    judge_words = ['ALD', 'Atomic Layer Deposition']
    flag = 0
    for j in judge_words:
        if j in text:
            flag = 1
    if flag == 1:
        return True
    else:
        return False

# %% [markdown]
# ## Elsevier

# %%
sen_dict = {}

# %%
import os
from tqdm import tqdm

elsevier = os.listdir('Elsevier2/')
for e in tqdm(elsevier):
    with open('Elsevier2/'+e, 'r', encoding='utf-8') as f:
        data = f.readlines()
        doi = data[0][:-1]
        if doi not in doi_year.keys():
            print(doi)
            continue
        start_words = ['Graphical abstract','Abstract', 'Corresponding author', 'Correspondence to:', 'Introduction', 'Keywords']
        s_find = 0
        for s in start_words:
            if s in data[1]:
                start = data[1].find(s)
                s_find = 1
        if s_find == 0:
            start = 0
        if 'Reference' in data[1]:
            end = data[1].rfind('Reference')
        else:
            end = len(data[1])
        fulltext = data[1][start:end]
        ald_or_not = ALD_justify(fulltext)
        opps, chas = get_opinions(sen_seg(fulltext))
        for o in opps:
            sen_dict[o] = {}
            sen_dict[o]['ald'] = ald_or_not
            sen_dict[o]['doi'] = doi
            sen_dict[o]['year'] = doi_year[doi]
            sen_dict[o]['senti'] = 'o'
        for c in chas:
            sen_dict[c] = {}
            sen_dict[c]['ald'] = ald_or_not
            sen_dict[c]['doi'] = doi
            sen_dict[c]['year'] = doi_year[doi]
            sen_dict[c]['senti'] = 'c'
# Out:
#  25%|██▍       | 21690/87300 [1:01:21<2:11:07,  8.34it/s]
# 10.1016/j.joule.2018.07.020
# 100%|██████████| 87300/87300 [3:33:06<00:00,  6.83it/s]

# %%
json_str = json.dumps(sen_dict, indent=4)
with open('sen_dict.json', 'w', encoding='utf-8') as json_file:
    json_file.write(json_str)

# %% [markdown]
# ## RCS

# %%
with open('sen_dict.json', 'r', encoding='utf-8') as f:
    sen_dict = json.load(f)

# %%
print(len(sen_dict.keys()))
# Out:
# 1582831

# %%
import os
from chemdataextractor import Document
from chemdataextractor.scrape import Selector
from chemdataextractor.scrape.pub.rsc import RscHtmlDocument
from chemdataextractor.doc import Document, Title, Heading, Paragraph, Citation, Table, Figure, Caption, Footnote
from chemdataextractor.reader.rsc import RscHtmlReader
from tqdm import tqdm


filepath = 'RSC/'
filename = os.listdir(filepath)

all_text = []
for fn in tqdm(filename):
    f = open(filepath+fn, 'rb')
    try:
        doc = Document.from_file(f, readers=[RscHtmlReader()])
    except:
        print(fn+'cannot work')
        continue
    fulltext = ''
    for e in doc.elements:
        if type(e) == Title:
            str_e = str(e).replace('\n', '')
            fulltext += str_e+'.'
        if type(e) == Paragraph:
            word_num = len(str(e).split(' '))
            if word_num > 100:
                str_e = str(e).replace('\n', '')
                fulltext += ' '+str_e
    htmlstring = open(filepath+fn, 'rb').read()
    sel = Selector.from_text(htmlstring)
    scrape = RscHtmlDocument(sel)
    doi = scrape.serialize()['doi']
    if doi not in doi_year.keys():
        doi = doi.lower()
        if doi not in doi_year.keys():
            doi = doi.upper()
            if doi not in doi_year.keys():
                print('doi not work')
                continue
    ald_or_not = ALD_justify(fulltext)
    opps, chas = get_opinions(sen_seg(fulltext))
    for o in opps:
        sen_dict[o] = {}
        sen_dict[o]['ald'] = ald_or_not
        sen_dict[o]['doi'] = doi
        sen_dict[o]['year'] = doi_year[doi]
        sen_dict[o]['senti'] = 'o'
    for c in chas:
        sen_dict[c] = {}
        sen_dict[c]['ald'] = ald_or_not
        sen_dict[c]['doi'] = doi
        sen_dict[c]['year'] = doi_year[doi]
        sen_dict[c]['senti'] = 'c'
# Out:
#   4%|▍         | 380/9399 [03:19<1:11:15,  2.11it/s]
# RCS_10338.htmlcannot work
#   5%|▍         | 465/9399 [04:05<1:23:56,  1.77it/s]
# RCS_10415.htmlcannot work
#  37%|███▋      | 3462/9399 [28:18<41:09,  2.40it/s]
# RCS_14023.htmlcannot work
#  61%|██████    | 5746/9399 [46:58<31:45,  1.92it/s]
# RCS_16082.htmlcannot work
#  75%|███████▍  | 7020/9399 [58:29<15:06,  2.62it/s]
# RCS_17229.htmlcannot work
#  84%|████████▍ | 7882/9399 [1:06:19<10:35,  2.39it/s]
# RCS_18005.htmlcannot work
#  91%|█████████ | 8510/9399 [1:11:44<10:15,  1.44it/s]
# RCS_18571.htmlcannot work
#  91%|█████████ | 8561/9399 [1:12:17<06:46,  2.06it/s]
# RCS_18617.htmlcannot work
# 100%|██████████| 9399/9399 [1:20:10<00:00,  1.95it/s]

# %%
print(len(sen_dict.keys()))
# Out:
# 1748100

# %%
json_str = json.dumps(sen_dict, indent=4)
with open('sen_dict.json', 'w', encoding='utf-8') as json_file:
    json_file.write(json_str)

# %% [markdown]
# ## Springer

# %%
with open('sen_dict.json', 'r', encoding='utf-8') as f:
    sen_dict = json.load(f)
print(len(sen_dict.keys()))
# Out:
# 1807886

# %%
from tqdm import tqdm
import os

doi_dic = {}
springer = os.listdir('springer_fulltexts/')
for s in tqdm(springer):
    with open('springer_fulltexts/'+s, 'r', encoding='utf-8') as f:
        data = f.readlines()
        fulltext = ''
        for d in data[1:-1]:
            fulltext+=d[:-1]+' '
        fulltext += data[-1][:-1]
        doi = data[0][:-1]
        if doi not in doi_year.keys():
            continue
        ald_or_not = ALD_justify(fulltext)
        opps, chas = get_opinions(sen_seg(fulltext))
        for o in opps:
            sen_dict[o] = {}
            sen_dict[o]['ald'] = ald_or_not
            sen_dict[o]['doi'] = doi
            sen_dict[o]['year'] = doi_year[doi]
            sen_dict[o]['senti'] = 'o'
        for c in chas:
            sen_dict[c] = {}
            sen_dict[c]['ald'] = ald_or_not
            sen_dict[c]['doi'] = doi
            sen_dict[c]['year'] = doi_year[doi]
            sen_dict[c]['senti'] = 'c'
# Out:
# 100%|██████████| 6433/6433 [17:44<00:00,  6.04it/s]

# %%
print(len(sen_dict.keys()))
# Out:
# 1823056

# %%
json_str = json.dumps(sen_dict, indent=4)
with open('sen_dict.json', 'w', encoding='utf-8') as json_file:
    json_file.write(json_str)

# %% [markdown]
# ## solar tile

# %%
with open('tile_dict.json', 'r', encoding='utf-8') as f:
    tile_dict = json.load(f)

for t in tile_dict.keys():
    if 'fulltext' in tile_dict[t].keys():
        fulltext = tile_dict[t]['fulltext']
    else:
        fulltext = tile_dict[t]['ab']
    opps, chas = get_opinions(sen_seg(fulltext))
    if opps != [] or chas != []:
        print(t)
        if 'doi' in tile_dict[t].keys():
            print(tile_dict[t]['doi'])
        for o in opps:
            print(o)
        for c in chas:
            print(c)
        print('\n')
# Out:
# Numerical simulation of a novel pavement integrated photovoltaic thermal (PIPVT) module
# 10.1016/j.apenergy.2020.116287
# Thereby , pavements are quite suitable for solar energy utilization as energy , either electricity or heat , which can be generated with few cars or pedestrians shadowing the surface when solar radiation is strong .
# Meanwhile , pavements also have enormous potential to generate electricity .
# Besides , PV pavement was also found effective for heat island mitigation , decreasing the surface temperature and ambient temperature by 5 °C and about 1 °C , respectively [ 19 ] .
# Additionally , high module temperature will also accelerate the rate of aging [ 21 ] .
# Thereby , necessary measures should be taken to extract the surplus heat timely and keep the PV pavement in relatively low temperature .
# Since there have been a lot of research and projects about the PV pavement confirming its mechanical feasibility , the PIPVT , another similar technology with the combination of PVT and pavement , is expected to be feasible in mechanical performance as well .
# 3.5 Performance evaluation criteria 3.5.1 System performance indicators Additionally , the electrical efficiency η ele , thermal efficiency η th and primary energy saving ( PES ) efficiency η PES are employed to estimate the performance of proposed PIPVT system .
# It can be seen that the simulated water temperature in tank shows a good agreement with that in experiment , with RMSD of 2.18 % and RE ranging from 0.12 % to 3.57 % , which is acceptable considering the accuracy of measuring equipment and the simplification of mathematical model .
# Therefore , in practice , a balance between the energy efficiency and the water temperature should be achieved considering specific requirements of users .
# Thereby , high transmissivity of the anti-slip layer dramatically contributes to high electrical efficiency , high thermal efficiency , and high temperature of the water in tank , which should be noticed when designing and manufacturing PIPVT modules .
# 4.2.2 Weather parameters Both the electrical and thermal energy are transformed from solar radiation , which is thus an essential factor to impact the performance of the PIPVT system .
# Thus , high ambient temperature is beneficial to generating more thermal energy and obtaining warmer water at the cost of an inapparent decrease of electricity generated .
# In summary , the significant improvement of thermal and PES efficiency could be achieved through increasing solar radiation and ambient temperature at the expense of a slight decrease of electrical efficiency .
# The aforementioned results reveal that the PIPVT module still has potential to generate more energy if the energy losses could be reduced .
# b ) The significant improvement of overall system performance could be achieved through increasing transmissivity of anti-slip layer , solar radiation and ambient temperature , estimated on primary energy saving ( PES ) efficiency .
# Compared with other renewable energy resources , solar energy has obvious advantages with respect to great abundance and easy availability [ 2–4 ] .
# ( 2 ) The ohmic losses of the PV module are negligible , and the PV efficiency is a function of temperature [ 24 ] .
#
#
# A Novel Investigation and Comparative Study on Building Integrated Photovoltaic Thermal (BIPVT) System
# 10.33889/IJMEMS.2019.4.2-038
# Previously comparisons and performance analysis were carried out for opaque and semitransparent system in non-optimized way but in the present case it has been optimized to get better results .
#
#
# Modular Rooftop Building-Integrated Photovoltaic/Thermal Systems for Low-Rise Buildings in India
# 10.18086/eurosun2018.06.12
# To accomplish this , a modular rooftop building-integrated photovoltaic/thermal ( BIPV/T ) system is designed , developed and modeled for an archetypical mixed-use building .
#
#
# Roofing Solar Panels of Planar and Concentrator Designs
# 10.4018/IJEOE.2020100102
# The article also proposes a method for manufacturing a prototype body for a solar roofing panel , manufactured using additive technologies , which will significantly reduce costs at the initial stage of creating a prototype due to the possibility of operational changes to a three-dimensional model followed by printing a modified and optimized model .
#
#
# Cost analysis for Construction of Photovoltaic Roofing
# 10.18421/TEM94-25
# As this is an ecological way of obtaining energy , there is a need for more discussion on this topic in order to ensure the sustainability of the planet .
#
#
# The Hybrid Photovoltaic-Thermoelectric Generator Configurations for Energy Performance Improvement
# 10.30880/ijie.2022.14.03.001
# Thermoelectric generators used to improve photovoltaic efficiency are amongst the widely adopted thermal management systems .
# The current hybrid system , as in the spectrum splitting method , has shown promises of improvement .
# Our preliminary results show the significant improvement in power output generated with the double side heat sink .
# But , lack the practicality to be deployed to the mass market , which is due to the complex structure that is not feasible to be turned into a consumer product .
# Thus , reducing the total hybrid system efficiency , as such both lack the capacity needed for active cooling .
#
#
# Air-cooled photovoltaic roof tile as an example of the BIPVT system - An experimental study on the energy and exergy performance
# 10.1016/j.energy.2020.117255
# The above mentioned background indicate the need for new methods , which allow the highest amount of heat removal from the photovoltaic panels , thanks to which it becomes possible to use the heated cooling medium , for example , for ventilation purposes .
# The use of many halogen lamps , according to the literature [ 25 ] , allows to develop an acceptable imitation of natural solar radiation .
# In such situation an improvement of the heat recovery requires an application of additional techniques , regarding passive heat transfer intensification , in example introduction of the turbulators .
# 4.7 Discussion and future plans The presented results of experimental investigations , conducted on a commercial PV roof tile , indicate , that there is a potential for the development of further research towards improving the intensification of heat removal from its back wall .
# During further considerations , the effect of ambient conditions also should be excluded as much as possible .
# Therefore , the solutions that reduce this temperature and utilize the recovered heat for other purposes ( for example for heating of the rooms ) are still being sought .
# It is worth to mention , that during the experiment it was difficult to stabilize the ambient conditions .
# The achieved thermal efficiency values indicate , that with the increase of solar radiation intensity and the increasing potential of heat transfer , the possibilities of heat removing from the wall of the PV roof tile are limited due to the insufficient temperature difference between the cooling medium and the hot element .
#
#
# 400W in Shingle SHJ configuration: promising optimization path for high power modules
# 10.1109/PVSC43889.2021.9518854
# Shingle integration is gaining more and more interest in recent module integration schemes as it combines several advantages , such as improved efficiencies , better aesthetics and even lower costs thanks to the simplified interconnection pattern .
# Heterojunction ( SHJ ) cells may not appear at first sight as the most adapted technology for shingling , as performance losses can be quite significant with the unpassivated edges generated during the cut step .
# But on the other hand , SHJ technology already benefits naturally from the strong knowledge acquired when combining ECA with TCO and low-temperature metal pastes .
#
#
# Photovoltaic Roof Tiles: The Influence of Heat Recovery on Overall Performance
# 10.3390/en12214097
# This is promising and proves the potential for air to be the working medium in such systems .
#
#
# URBAN PHOTOVOLTAIC POTENTIAL OF INCLINED ROOFING FOR BUILDINGS IN HERITAGE CENTERS IN EQUATORIAL AREAS
# 10.3992/1943-4618.13.3.45
# In situ renewable energy production is a favourable alternative for reducing pollution and combating climate change .
# Thermal impact of adhesive-mounted rooftop PV on underlying roof shingles
# 10.1016/j.solener.2018.09.079
# To realize this huge market potential , however , the non-hardware ( soft ) material and installation costs must be reduced ( Ardani et al. , 2013 ; Barbose et al. , 2013 ; Morris et al. , 2013 ; Morris et al. , 2014 ) .
# To ensure the sufficient structural integrity , we studied the wind uplift , creep performance and durability of the adhesives ( Honeker et al. , 2016 ) .
# In addition , since a typical roof accounts for about 14 % of the total cooling loads in a residential building ( Buildings Energy Databook , 2010 ) , the potential for heat build-up caused by adhesive-mounted rooftop PV may increase the cooling demand of the building .
# It was concluded that an appropriate air gap could reduce the heat load of the building by at least 1.85 kWh/m2 per year .
# Thermal isolation reduces the influence of the junction potential caused by the dissimilarity of the TC wire and the wire leads .
# These soft costs remain higher in the US than in most other countries , due in part to a higher cost of installation and complicated code approvals ( Barbose and Darghouth , 2015 ) .
# The use of adhesives to attach lightweight PV modules directly to a residential roof has the advantages of speed , simplicity and reduction of skilled labor .
#
#
# An Adaptive Sensorless Control Technique for a Flyback-Type Solar Tile Microinverter
# 10.1109/TPEL.2020.2992779
# The proposed control system eliminates both the high frequency inductor current measurement as well as the photovoltaic ( PV ) module current measurement .
# The elimination of current sensors from the circuit lowers the overall cost and reduces measurement noise introduced into the control system .
#
#
# Root cause analysis of solar cell cracks at shingle joints
# 10.1016/j.solmat.2022.111590
# In summary , the shingle technology promises high power density solar modules while at the same time offering a valuable aesthetic look by avoiding the visible metal ribbons and solar cell gaps .
# For these specific applications , there is a huge potential of around 1400 GW only in Germany [ 1 ] .
# We used optimized string interconnectors to reduce mechanical stress and connected them with eutectic Sn63Pb37 solder .
# Again , losses in the fill factor , ( − 1.1 ± 0.3 ) % after TC100 , and ( − 2.6 ± 1.3 ) % after TC1000 , are responsible for the losses in power .
# • There are ( mechanical ) properties of the ECA which favor or mitigate the crack formation .
# The mechanical stiffness and the CTE are key properties for the thermal expansion behavior and therefore likely to be relevant for the mechanism .
# If that were the case , a thermal laser separation process ( TLS ) would offer a possibility to reduce cracking .
# Eitner found that linear elastic behavior is a good approximation for Tedlar based multi-layer back sheets in the investigated temperature regime [ 2 ] .
# However , it is likely , that the material properties play a crucial role in the defect occurrence .
# The mechanism responsible for the cracking also shows that the coefficient of thermal expansion of the ECAs plays a crucial role .
# However , along with the promising properties also new technological challenges arise .
# Since the CTE is an intrinsic and temperature dependent property of both materials , the implementation of this strategy is rather challenging .
# The findings are in very good qualitative agreement with the results of the microscopic analysis of cross sections from the experimentally investigated samples .
#
#
# Fiber-reinforced mortar for secondary roofing slabs
# 10.1002/suco.202000275
# On the other hand , the specimens containing only structural synthetic fibers achieved the requisite residual load-carrying capacity for secondary roofing slabs and also exhibited enhanced ductility through high flexural toughness , thereby sustaining large deflections .
#
#
# Development of a New Dynamic Test Method to Determine the Wind Pressure Resistance of Photovoltaic Roof Assembly (PVRA)
# 10.1520/JTE20210671
# However , there is no guidance on the resistance aspect of the PVRA .
# Once standardized , this new protocol will ensure that PVRA integrity is maintained and PV performance is optimized .
#
#
# Roof with metal sheets and PV-systems - practical knowledge
# 10.1002/stab.202100077
# The following article goes into detail to the before mentioned metal sheets regarding the formal basis , loadings , static design , occasional or repeated access of persons and requirements due to corrosion .
#
#
# Evaluation of a PV-TEG Hybrid System Configuration for an Improved Energy Output: A Review
# 10.14710/ijred.2021.33917
# The use of a wide range of the solar spectrum through the solar cells will increase electricity generation and thereby improve energy supply .
# These generators also enhance device efficiency and reduce the amount of heat that solar cells dissipate .
# Several experiments have been carried out to improve the hybrid PV-TEG system efficiency , and some are still underway .
# Furthermore , different hybrid system integration methods and experimental and numerical investigations in improving the efficiency of PV-TEG hybrid systems are also discussed .
# This paper also assesses the effect of critical parameters of PV-TEG performance and highlights possible future research topics to enhancing the literature on photovoltaic-thermoelectric generator systems .
#
#
# Development of walkable photovoltaic floor tiles used for pavement
# 10.1016/j.enconman.2019.01.035
# In addition , solar panels need ventilation to keep cool and perform optimally [ 15 ] .
# A finite element modelling approach was employed to predict the performance of solar road panels on a variety of structural bases , concluding that the solar road panel can withstand the traffic loading and even improve the expected structural performance of the base [ 17 ] .
# The heat-resistance temperature can be up to 288 °C , so there is no need to worry about whether it will be broken under long time sun exposure .
# Poon and the colleagues from Renewable Energy Research Group in The Hong Kong Polytechnic University who provided great support in this research .
# However , this cutting edge technology is under its infant development stage and still has some problems , for example , such solar panels are very heavy so it is very difficult to install it , and the anti-slip coating , which provides grip to the surface , has become delaminated due to long term sun exposure and temperature fluctuations .
#
#
# Experimental dataset of seasonal behaviour of a hybrid solar tile
# 10.1016/j.dib.2020.106649
# • The data set could be reused in future research studies to design and test new prototypes and materials , making choices also in order to evaluate the best applications for integration in thermohydraulic systems .
#
#
# Smart energy harvesting performance of photovoltaic roof assemblies in Canadian climate
# 10.1080/17508975.2020.1802694
# The aim of the current research study is to evaluate the new energy harvesting technologies such as a thin-film PV integrated roof system that could serve as a conventional roofing for weather protection while generating clean solar electricity , and the new generation micro inverters that have the potential to outperform string inverters under shading and snow-cover conditions .
#
#
# Ultralight Energy Converter Tile for the Space Solar Power Initiative
# Analysis of the sources of mass and inefficiency suggest a path towards achieving dramatically higher performance with future designs .
#
#
# Development of a Competitive Thermoplastic Vulcanizate Roofing Sheet from Natural Rubber and High-Density Polyethylene
# 10.1109/MERCON52712.2021.9525658
# The developed TPV sheet is cost competitive and suitable for the high-class customer segment .
#
#
# Carbon footprint associated with a mono-Si cell photovoltaic ceramic roof tile system
# 10.1002/ep.13120
# A sensitivity analysis verified that utilization of poly-Si yielded a carbon footprint of 822 kg CO2-eq but its inherent lower space-efficiency was an issue , as a larger surface is required ( which is not possible with roof tiles , rendering this option not viable ) .
#
#
# A Research for the Influence of Tilt Angles of the Solar Panel on Photovoltaic Power Generation
# The development of new energy industry together with environmental protection is converting photovoltaic industry into a more attractive energy supply option .
# At the consumption level , solar PV is the most widespread generation technology due to infinity , easy maintenance and declining running costs .
# Data on roof renovation and photovoltaic energy production including energy storage in existing residential buildings
# 10.1016/j.dib.2022.107874
# Keywords Roof insulation Energy efficiency PV systems Residential building retrofit Building energy simulations Specification Table Subject Energy .
#
#
# Design and development of energy efficient re-roofing solutions
# 10.1016/j.renene.2019.11.128
# Keywords Energy-efficient building materials Retrofit strategies BIM Solar panels 1 Introduction In order to develop a more holistic method for energy efficient refurbishment of buildings , it is necessary to focus on decision-making processes , particularly with regard to building envelope components .
# Retrofit and refurbishment strategies can result in energy efficiency improvements and cost reduction initiatives for buildings .
# The proposed methodology supports development of sustainable energy retrofitting strategies for the existing roofs .
# Moreover , the study indicated that appropriate insulation could play a key role in achieving the optimal performance in the building retrofit .
# There has been an increasing trend and interest in retrofitting the roofs of existing buildings for energy and sustainability improvements .
# Pisello et al . [ 7 ] developed a cool-green roof that could be considered as an approach for roof retrofitting , and a solution for improving the quality of the urban environment .
# A study by Gourlis and Kovacic [ 10 ] presented an analysis of refurbishment strategies for a historical building , and the results showed that the thermal refurbishment plays a crucial role in reducing energy consumption by up to 52 % .
# ⁃ Ensuring the commitment from the property owner ⁃ Benchmarking the performance of the existing building ⁃ Energy auditing and assessment of retrofit opportunities ⁃ Identifying retrofit measures to go from the existing case to the required performance level ⁃ The implementation phase ⁃ Continuous monitoring to ensure the system is working as planned .
# Baldwin et al . [ 12 ] highlighted the importance of developing retrofitting solutions with respect to energy saving techniques and green technologies .
# The use of sustainable retrofitting strategies for buildings still plays the most important role in saving energy efficiency and renewable energy production .
# In order to achieve sustainable retrofitting targets , it is important to consider envelope retrofits combined with on-site renewable energy generation .
# Retrofit of roofing systems can play a vital role in achieving sustainable development goals .
# In order to fulfil these objectives , it is necessary to develop sustainable roof retrofitting approaches based on renewable energy sources , appropriate selection of materials , existing climatic conditions , and building characteristics .
# Proper selection of insulating material is considered an important factor in reaching the desired energy reduction in retrofit roofing systems .
# In the context of retrofitting buildings , it is important to develop assessment frameworks and decision-making models to find to an optimal renovation strategy .
# The study reported in Ref . [ 14 ] presented a decision-making framework that estimates the retrofit benefits in terms of reduction of life-cycle cost for a specific building .
# Decision-making frameworks can play a key role in evaluating sustainability of insulating materials and achieving recommended insulation values ( e.g. , R-values ) in retrofit systems .
# In this study , glass wool , hemp fibers , kenaf fibers , polystyrene foam , polyurethane , and rock wool were the most promising materials in terms of the socio-economic and environmental impacts .
# BIM based tools can provide simulation and visualization options for sustainable development and refurbishment projects , and can also be used to minimize uncertainties in building energy modeling processes and energy-driven retrofits .
# Such an approach offers efficient installation methods for both refurbishment and new build applications in the field of roofing systems .
# In fact , use of a proper membrane system is crucial for roof retrofitting system based on heat transfer and thermal performance analysis , as well as waterproofing criteria .
# Minimization of transfer of heat into building is a key factor to foster energy conservation .
# Hence , it is important to develop appropriate socio-technical and sustainability interventions toward sound strategies for roofing retrofit systems .
# 2 Energy-efficient building materials for refurbishments Assessment of building materials in terms of energy efficiency has become one of the most important factors in the built environment .
# In order to conduct energy efficient and sustainable refurbishments , it is necessary to consider the amount of energy consumed by the materials used in construction and maintenance of buildings during their life cycle .
# Energy-efficient materials can play a key role in promoting energy saving and carbon reduction in the increasing expanding field of building retrofitting .
# The selection of appropriate materials along with providing better thermal properties ( e.g. , thermal conductivity/resistance , radiation/light transmissibility , and thermal storage ) is an important part of energy efficiency retrofit projects .
# Some of these solutions can significantly reduce energy consumption and provide long-term benefits .
# EPDM membranes can be mechanically-attached , adhered , and ballasted .
# Building energy efficiency retrofit can be greatly improved by selecting appropriate materials with the minimal environmental impacts and considering the life cycle of materials , from cradle to grave .
# It is an important measure of the environmental performance and efficiency of building materials .
# Furthermore , for cost-effective retrofitting and new construction of building envelope components , it is important to establish a relationship between initial embodied energy of building materials and real operational energy consumed .
# The use of low embodied energy materials is widely regarded as a key factor in achieving energy efficiency and climate change goals .
# Growing environmental issues and concerns have led to an increased focus on the integration of lightweight recyclable materials into retrofitting as well as new construction projects .
# For example , heat reflectivity of aluminum foil can be used to improve insulation performance in building systems .
# From the sustainability point of view , aluminum alloy structures provide excellent integrity when the long-term approach is being adopted [ 27 ] .
# Furthermore , a flexible grid , supporting infrastructure , and a suite of enabling technologies are also required for installation of a rooftop PV system [ 28 ] .
# However , its dependence on effective installation techniques has been associated with potential reduction in power output of PV arrays when used as an integral building element .
# They are considered to have the greatest potential for use in solar energy conversion .
# They play an important role in maximizing energy harvesting and facilitating possibilities for a variety of applications .
# They play an important role in maximizing energy harvesting and facilitating possibilities for a variety of applications .
# Application of photovoltaic thin film modules directly into conventional construction materials can provide the possibility of designing appropriate shapes .
# 4 Roof assembly guidelines It is necessary to evaluate long-term performance of roof systems and existing conditions prior to design and installation of a new roof system or re-cover application .
# There are several important factors such as drainage requirements , structural roof deck conditions , and potential leak sources consideration of which can contribute to successful performance of a roofing system .
# In this context , siphonic roof drainage is an efficient type of drainage system that is mostly suitable for large buildings and can be used with all types of waterproofing systems ( Fig . 6 ) .
# It can provide guidance to prevent adverse effect of uncontrolled air leakage through the roof assembly ( Fig . 7 ) .
# Although refurbishment of a sloped roof can be accomplished by covering of roofing materials and elements , there is still great potential for an economic and environmental design of renovation concepts .
# It is expected that sustainable refurbishment will be effective in reducing the amount of GHGs emitted by existing buildings .
# In order to address sustainable refurbishment with high-energy efficiency , it is imperative to better understand the difficulties in the replacement of existing roofing systems with retrofit materials .
# Therefore , consideration should be given to the development of appropriate building materials that are compatible with existing roof system in order to improve thermal performance , efficiency and sustainability .
# The study uses green retrofit and sustainability-inspired initiatives such as designing and testing a conceptual model for a new roofing composite that will sit on top of the existing roof not only to improve the aesthetic qualities and thermal insulation but also to generate renewable electricity .
# 6.1 Thermal insulation In order to help choose the most appropriate solution for refurbishment projects , it is important to create multiple viable options and then provide a comparison .
# 6.2 Proposed detail of new roof Given the importance of considering sustainable refurbishment as a decision factor , an example design of the roofing system is presented for retrofit of the existing system .
# It is widely used in low-slope buildings and can play a key role in waterproofing applications subject to roof retrofit/replacement .
# It is important to mention that this was only one example showing how the performance can be improved .
# This study aimed at designing and developing energy efficient re-roofing solutions .
# 105 2015 358 367 B. Roberts , M. Webber and O. Ezekoye , `` Development of a multi-objective optimization tool for selecting thermal insulation materials in sustainable designs '' , Energy and Buildings , vol .
# It is desirable to carry out a deep refurbishment and to maintain the building in working condition with minimum energy consumption and cost .
# Increasing the transmission performance of a conventional 110 kV cable line by combining a hydronic concrete pavement system with photovoltaic
# 10.1007/s00202-020-01167-4
# In particular , the PV cells would generate waste heat and direct current electricity from sunlight ( using the PV effect ) , the cable bedding would conduct waste heat well from the cables to the heat collecting pipes of the HCP system ( by improved heat conduction ) , while the HCP system would collect and store waste heat from the PV cells and cables as well as some heat from the Sun ( using the heat exchanger principle and heat storage capability ) .
#
#
# A Novel Control System for Solar Tile Micro-Inverters
# Current sensors are usually required in the micro-inverter circuitry in order to perform maximum power point tracking ( MPPT ) , as well as in the current loop to shape the output current to a sinusoidal waveform synchronous with the utility grid .
# The proposed method in this paper is able to estimate the current mathematically , thus , eliminating the need for current sensors on the converter .
# Simulation and experimental results show the feasibility of the proposed technique and demonstrate its superior performance .
#
#
# A Review of Roofing Methods: Construction Features, Heat Reduction, Payback Period and Climatic Responsiveness
# 10.3390/en11113196
# Some of these methods can eliminate the need of installing HVAC ( Heating Ventilation and Air-conditioning ) systems and others can achieve a high percentage of heat reduction if they are the right choice and they are implemented in the right circumstances .
# An incorrect selection could result in mild to severe energy penalties .
#
#
# Cool roof coating impact on roof-mounted photovoltaic solar modules at texas green power microgrid
# 10.1016/j.ijepes.2021.106932
# In order to improve the building energy efficiency , several studies were developed about cool roofing according to climate change and urban evolution .
# For building-level energy saving purposes , cool roof materials were adopted by several countries to reduce urban temperatures and ozone concentrations , and potentially to decrease radiative forcing on a global scale [ 15 ] .
# Consequently , lower surface temperatures reduce heat transfer between the roof and the building , helping to control the cooling load .
# Additionally , cool roofing materials are affordable , efficient , and durable , and they can be applied to various types of roof [ 19 ] .
# Therefore , the proposed PV system guarantees to provide the required energy generation despite upcoming blackouts , and lifespan of cool roof-mounted solar modules for 25 + years .
# Additionally , 186 solar modules were designed with an optimal arrangement due to the accomplishment of both a beneficial commercial project and a successful experimental study .
# 3.2 Optimal module arrangement design In order to accomplish both a profitable commercial project and a successful research study , the solar modules had to be designed with an efficient arrangement for the solar installation subcontractor .
# Therefore , the optimizer can adjust the DC voltage to provide the appropriate conditions for the inverter to convert the voltage efficiently .
# The fully integrated design of the SkyBox system eliminates the need for external charge controllers and communication boxes , significantly cutting installation time and cost .
# To benefit the occupants , allowing them to use all of these necessary devices in the absence of grid power , an essential load panel and a non-essential load panel were implemented .
# 4th achievement : The project performance confirmed that the 156.63 kWh of battery storage was sufficient for the demands to be able to continually consume electricity for 5.55 + hours after a blackout .
# Therefore , introducing the cooling techniques has successfully reduced summer overheating circumstances to carry out the global energy consumption reduction objectives .
# ) , must manage the grid to prevent brownout and blackout crises .
#
#
# Solar surfaces: A bad idea or tomorrow's mainstream application?
# 10.1557/mre.2019.11
# In this article , we explore the potential value of integrating PV into surfaces and the challenges to achieving that value .
# This motivates the question : `` Was integrating PV into the desired product a bad idea or is it an idea whose time has not yet come ? ''
#
#
# A Modified Particle Swarm Optimization for Parameters Identification of Photovoltaic Models
# In MPSO , in order to explore more promising regions of the search space , a mutation operation disliked by differential evolution is employed to improve the quality , of personal best of each particle as well as the glolval best of the current population .
#
#
# PVCOM Project: Manufacture of PV Modules Encapsulated in Composite Materials for Integration in Urban Environments
# 10.1007/978-3-030-12804-3_4
# Despite traditional glass-glass configuration , the use of composite materials for encapsulation is proposed because its high transparency , low weight and great integration possibilities .
# Conceptual designs are based on legal and end-user 's requirements and involved technologies limitations .
#
#
# A system dynamics analysis of the alternative roofing market and its potential impacts on urban environmental problems: A case study in
# 10.1016/j.resconrec.2019.104556
# Buildings therefore play an important role in urban sustainability , making the urban construction industry an ideal target through which to help mitigate these problems .
# Similarly , the choice of roofing system will have either reinforcing or balancing effect on building ’ s energy saving potential , which may counter the potential increase in energy demand due to population growth .
# Since then , growing interest in ARSs has led scholars to contribute significant amounts of research to today ’ s ARS literature , including extensive research on the potential environmental and practical benefits of GRs , SRs , and GRIPV roofs as well as their associated costs and/or savings .
# In this regard , Saiz et al . ( 2006 ) evaluated the life cycle environmental benefits of standard and GRs in terms of GR ’ s potential for heat flux reduction , annual energy saving , and summer cooling load , and concluded that replacing standard roofs with GRs resulted in environmental reductions of up to 5.3 % .
# Susca and Gaffin ( 2011 ) analyzed the impacts of GRs on the UHI effect , CO2 emissions , and energy use , and concluded that green roofs are viable options to counteract these impacts , underlining the significance of building materials in that regard .
# Bianchini and Hewage ( 2012b ) evaluated the environmental benefits of GRs ( i.e emission generation vs. pollution removal capacity ) , and concluded that sustainable production of green roof materials is needed to maximize green roof benefits , which confirmed Susca and Gaffin ( 2011 ) on the importance of adequately selected building materials .
# Refahi and Talkhabi ( 2015 ) investigated GR ’ s potential to reduce energy consumption using energy analysis with thermal load simulation , and found the magnitude of these reductions to be dependent on climate , with a payback period of 25–57 years .
# Several scholars have investigated the ARSs with regard to their potential for reducing the UHI effect .
# Razzaghmanesh et al . ( 2016 ) investigated the potential of GRs to mitigate the UHI effect , and concluded that GRs have significant cooling effects during the summer and insulation capacity during the winter .
# Costanzo et al . ( 2016 ) compared cool roofs and GRs based on their UHI effect and energy consumption reduction potentials , and found that although cool roofs outperform GRs in reducing the UHI effect , GRs have a better energy performance .
# Similarly , Li and Bou-Zeid ( 2014 ) investigated the potential of cool roofs and GRs to mitigate the UHI effect using a combined regional climate and urban canopy model , and found that the application of cool roofs and GRs reduced the UHI effect almost linearly .
# Solcerova et al . ( 2017 ) investigated several sedum-covered GRs to analyze their effects on air temperature above the surface based on-site measurements , and concluded that GRs are more beneficial for decreasing air temperature at night .
# The scholars concluded that GRs are effective in providing thermal insulation to a building , and that semi-intensive GR system outperforms extensive-GR system overall .
# Hui and Chan ( 2011 ) conducted an experiment on GRIPV roof , using energy simulations and field measurements , to investigate the energy-related benefits of green-solar integration , and concluded that GRIPV systems could achieve better energy conservation relative to other existing alternatives .
# Lamnatou and Chemisana ( 2014 ) examined the life-cycle performance of a GRIPV roof relative to a PV-gravel roof , a GR , and a gravel roof , and found material production to be the most energy-intense process , concluding that GRIPV roofing was a viable option with multiple benefits , confirming the significance of building materials , as discovered by previous research .
# 4 A lack of research was also observed in the literature in terms of analyzing the potential long-term impacts of ARSs while also taking into account the internal and external dynamics of the applications of these systems , as well as how these dynamics might affect their overall long-term benefits .
# 5 Several studies point out the need for further research on the integration of green and PV roofs ( Brudermann and Sangkakool , 2017 ) and for effective policy options that will encourage the use of alternative roofing systems ( Jean et al. , 2015 ; Schindler et al. , 2016 ) .
# 1.2 The objective of the study Although ARSs are able to help mitigate urban environmental concerns and support urban sustainability , the application ( i.e . market shares ) of these systems is still relatively marginal in Orlando and in the U.S. overall ( Chemisana and Lamnatou , 2014 ) .
# Thus , the environmental concerns that the ARS industry seeks to address continue to contribute to significant environmental and socioeconomic problems on a long-term , macro-level scale .
# The long-term impacts of these hindrances on the ARS market must be properly analyzed and addressed in order to contribute to developing an optimum solution with which to lessen these impacts and promote more effective growth in the ARS market .
# The present study considers ARSs to be an effective innovation for the sustainable built environment , and the adoption of these systems is analyzed in this study within the context of the diffusion of innovation theory , using an SD model based on the generalized version of the Bass diffusion model ( a.k.a .
# 1 Problem/Hypothesis Identification : Despite the proven potential of alternative roofing systems to significantly reduce urban runoff , the UHI effect , energy consumption , and GHG emissions , their long-term impacts and overall potential with respect to their market penetration and sustainability benefits must be covered by the system boundary as they apply to Orlando ’ s alternative roofing market .
# 5 Validation : Various tests are applied to validate the model in order to confirm that it serves as a reasonably accurate depiction of the modeled system in reality .
# Alternative roof adoption strategies for new roofing construction will also be essential , among other possible policy initiatives .
# 3.1.2 Green roof market Green roof market penetration demonstrated potential for future growth , with 2040 green roof market shares increasing by as much as 149 % ( compared to the BAU scenario ) with sufficient investment in Orlando ’ s green roof market , as shown in Fig . 3b .
# 3.1.3 Solar roof market The solar roofing industry is the most mature out of the three alternative roofing markets considered in this study , and consequently has the most potential for future market penetration , as shown in Fig . 3c .
# However , as shown in Fig . 4 , the GRIPV market , once introduced and given sufficient policy support , has significant market penetration potential , enough to surpass green roofing under some policy scenarios ( e.g . Green2+Solar2+GRIPV ) .
# However , urban runoff results at the building level – specifically a comparison of the individual performances of each alternative roofing option – imply the potential for more optimistic results if green/GRIPV roofing technology can achieve further growth and development beyond what was simulated in this study , as shown in Fig . 5 and provided in Section S1.7 .
# 3.1.6 The UHI effect The simulation results indicate significantly more potential for improvement with respect to the UHI effect in Orlando as opposed to the urban runoff results .
# The “ Solar2+GRIPV ” scenario demonstrates the best numerical results in this regard , indicating that solar and GRIPV roofing will be especially effective at reducing the UHI effect .
# However , the UHI effect results at the building level imply the potential for far more optimistic results if green/GRIPV roofing technology can achieve further growth and development beyond what was simulated in this study , as provided in Section S1.7 and Fig . 6 .
# This is because solar and GRIPV roofing options can both actively generate electricity via solar PV technology to offset energy requirements and provide the passive cooling benefits previously discussed with respect to the UHI effect , whereas green roofs can only passively reduce energy demand by reducing the need for air conditioning and other forms of cooling .
# The maximum possible goal contribution in this regard was found to be only 4.13 % of the established per-capita energy savings goal by 2040 , though this was a 546 % improvement compared to the BAU scenario and a 488 % improvement compared to the GRIPV-only ( “ BAU + GRIPV ” ) scenario .
# This indicates a 546 % improvement compared to the BAU scenario and a 488 % improvement compared to the GRIPV-only scenario .
# 3.2.3 Solar roof market As shown in Figs . 11a and 11b , the uncertainty results for the solar PV/BIPV roof market showed its potential to achieve market penetration levels as high as 3,000–3,840 acres ( 12 – 14 km2 ) by the year 2040 under optimal BAU or GRIPV-only market conditions .
# These uncertainty results indicate that , with further attention to market conditions as needed , solar PV/BIPV roofing can become a more competitive roofing option in Orlando than what was previously observed in the policy analysis results , without being as heavily dependent on external policy support as the green or GRIPV markets might be .
# Like the green roof market , the GRIPV roof market demonstrated little sensitivity to external market influences .
# Although continued policy support for green and GRIPV roofing in Orlando will be a crucial first step to encouraging more pervious urban building materials and thus reducing urban runoff more significantly in the future , the policy analysis results have already shown that further policy intervention will also be necessary for this purpose ( Fig . 11 ) .
# Furthermore , these findings indicate that urban runoff in Orlando is unlikely to decrease on a citywide scale in the near future despite the clear effectiveness of green/GRIPV roofing for reducing runoff on a building scale , as also shown in Fig . 5 .
# This high degree of variability indicates that the UHI effect in Orlando will depend more on future technological and practical development in the urban roofing industry as a whole than on the policy support of one or more particular roofing options without such development .
# However , since green and GRIPV roofing are significantly more effective in this regard on an individual scale , as also shown Fig . 6 , it is possible for the green and GRIPV roofing industries to play a larger role in counteracting the UHI effect in the future if they can achieve sufficient market growth .
# These results indicate that greater contributions toward the established 2040 energy savings are more likely to depend on future technological and practical development in the urban roofing industry as a whole than on the policy support of one or more particular roofing options without such development .
# Among the studied roofing alternatives , the solar roofing market is expected to maintain its relative dominance in the alternative roofing industry and has the most potential for future growth .
# In contrast , the green and GRIPV roof markets , despite also demonstrating significant potential for future market growth , are far more static in terms of their gross investment costs ( excluding available savings and incentives ) and practical feasibility .
# Therefore , policy support and further technological development for green roofing and the green roof components of GRIPV roofs will both be essential in the future , as also concluded by Berto et al . ( 2018 ) .
# However , based on the simulation results , it is possible to mention some intrinsic improvements that could be developed to foster the alternative roofing market as the followings ; • Shifting toward more lightweight and/or more user-friendly green roof designs , e.g . modular GR systems .
# This holds true given a sufficient combination of policy initiatives and future industrial and technological enhancement for the alternative roofing industry as a whole .
# However , ARSs – particularly GR systems – at the building level yield significant improvements .
# Nevertheless , it can be concluded that the green and GRIPV roof markets have more potential to reduce the UHI effect , particularly with the introduction of GRIPV roofing .
# Therefore , although policy support for alternative roofing will be important in the future , further technological and market development will be essential to further reduce the UHI effect .
# Nevertheless , continuing to invest in market growth and future development for GRs – particularly GR modules with greater carbon sequestration potential ( e.g . semi-intensive and intensive green roofs ) – will continue to be crucial to reducing energy demand and GHG emissions in the future .
# 5 Limitations and future remarks Due to the relatively generalized nature of the developed model and of this study as a whole , several factors were not considered that might limit the study ’ s ability to provide further insights .
# Although the behaviors of these outputs was still found to be reasonably accurate based on available information on their real-world counterparts , more historical data on all five of these parameters would be very helpful to validate future models in which they are featured .
# Likewise , additional policy efforts could potentially target one or more of these factors ( esp .
# in urban runoff and the UHI effect ) , but these additional policy initiatives were beyond the scope of this study and were therefore excluded .
# However , there are still significant obstacles in today ’ s alternative roofing ( AR ) industry , and the extent to which these obstacles hinder the long-term market penetration of ARSs is not yet fully understood .
# There are several constraints restricting the market growth ( or diffusion ) of ARSs and thus hindering their overall potential to address these problems , and Brudermann and Sangkakool ( 2017 ) identified the following three major hindrances to ARS adoption based on interviews with academic , industrial , and sociopolitical green roof experts : • Political constraints , • Skepticism of potential adopters , and • Lack of knowledge ( esp .
# Therefore , alternative roofing for new building construction was not taken into account .
# Also , the green roof market was found to be very resilient to adverse market conditions , with its 2040 market shares never decreasing by more than 5.4 % relative to the BAU scenario .
# Although green roof market shares have been found to never exceed those of the solar roof market in any of the tested policy scenarios , the findings indicate that the green roof market can still potentially thrive with more diverse investment portfolios in the alternative roofing industry as a whole .
# Nevertheless , this decrease was noticeably less drastic in some scenarios in which both alternatives received policy support ( e.g . the “ Green2+Solar2+GRIPV ” scenario ) , while some multiple-policy scenarios ( e.g . the “ Green1+Solar2+GRIPV ” scenario ) still demonstrated a net increase in 2040 solar roof market penetration compared to that of the BAU scenario , meaning that a balanced policy solution can still be found without significantly compromising the future of Orlando ’ s solar roof industry .
# Overall , though the market share of GRIPV roofing is still likely to remain marginal compared to that of conventional roofing , it shows to be a promising alternative in Orlando .
# ...
# This database provides information on energy prices , feed-in-tariffs , installation costs , costs of alternative materials , financial mode , incentives , and discount rate .
# Concessions are not estimated as there is no BIPV-specific government incentive scheme applicable to this case study .
# The BIPV cost-benefit assessment process helps to identify life-cycle costs and life-cycle economic savings of the alternative feasible BIPV designs .
# Both single and multi-objective optimization are useful to balance competing BIPV design variables [ 37,88 ] .
# 5 Conclusions Buildings have the potential to accommodate renewable energy solutions and to achieve zero carbon emission targets .
# BIPV envelopes are an excellent renewable solution to achieve zero-carbon buildings .
# Therefore , BIPV designs need to be identified in the early design phase to ensure that appropriate BIPV solutions are identified in terms of cost and energy performance .
# Therefore , multi-objective optimisation is beneficial in the early design phase to identify feasible BIPV design options .
# Further , the proposed optimisation method provides the opportunity to select several feasible BIPV design options instead of one BIPV design solution .
# The optimisation results demonstrate the ability to generate optimum BIPV design options in the early design phase .
# It is also supported by the industry partners in this research project .
# Keywords Multi-objective design optimization Building-integrated photovoltaics Early design phase Life cycle cost Life cycle energy Nomenclature Eb POA beam component Eg POA ground-reflected component Ed POA sky-diffuse component .
# The main reasons for the lack of uptake of BIPV projects is that the integration of PV into building envelopes poses complexities in the design process and high investment cost [ 11–12 ] .
# Calculating these conflicting performance criteria for different design requirements in BIPV projects can be a difficult task .
# Furthermore , lack of consideration for PV integration in the building envelope in the early design phase may increase the complexities of the design process and cause failure of the BIPV system [ 11 ] .
# However , many tools and software packages used for BIPV designs focus on simulation and do not consider the optimisation of BIPV designs to facilitate decision making in early design stages [ 21 ] .
# In addition , the optimization processes have not considered the impact of BIPV modules/products as a design variable .
# ( 6 ) ) and the operational and maintenance costs ( Eq .
# NSGA II is a proven multi-objective optimization method for handling vast numbers of variables and potential solutions under multiple objective functions [ 36,57 ] .
# Especially , buildings in suburban areas have large roof areas and small shading effects , making them suitable for BIPV roof applications [ 72 ] .
# Installation costs : Installation costs include costs of labour and equipment .
# Overall , the results of this study show that there is great potential for BIPV roof sheet and BIPV skylight applications .
#
#
# Heterogeneous SoC Integration with EMIB
# IP availability on the same technology node on the same industry process is also not always possible because of design complexity , features and schedule .
#
#
# Plasma-wall interaction on the divertor tiles of JET ITER-like wall from the viewpoint of micro/nanoscopic observations
# 10.1016/j.fusengdes.2018.01.051
# Keywords JET-ILW Divertor Erosion-deposition Fuel inventory 1 Introduction In the D-T burning fusion reactors , tritium inventory on the plasma facing components ( PFCs ) should be kept to minimum not only for maintaining a fuel balance but also for ensuring radiological safety .
# Tungsten ( W ) is one of the potential candidates for PFCs in the fusion reactor because it has a low solubility of hydrogen isotopes and excellent thermal properties .
# Generally , topological judgment is difficult by SE-SEM image , but BS-SEM image is helpful for judging .
#
#
# Investigation of deuterium trapping and release in the JET divertor during the third ILW campaign using TDS
# 10.1016/j.nme.2019.03.012
# 1 Introduction JET has now operated three operational periods with the ITER-like Wall – 2011–2012 ( ILW-1 ) , 2013–2014 ( ILW-2 ) and 2015–2016 ( ILW-3 ) so it offers a unique opportunity to study plasma-wall interactions ( PWI ) that will take place whilst operating the next step fusion device ITER .
# Therefore , plasma exposition at low surface temperature at low trapping sites can take place .
# The energy chosen is high enough for creating sufficient amounts of implantation-induced defects for trapping D in W at RT .
#
#
# Behaviour of Multi-layered Hybrid Fibrous Ferrocement Panels
# 10.1007/978-981-15-7827-4_18
# This work can lay a path to development of lightweight roofing and supporting structures like thin shells , silos , etc .
#
#
# Analysis of the outer divertor hot spot activity in the protection video camera recordings at JET
# 10.1016/j.fusengdes.2018.12.079
# This issue has become especially important after the installation of the ITER-like wall ( ILW ) [ 2 ] , where the carbon-fibre composite ( CFC ) tiles in the divertor were replaced with bulk tungsten ( W ) and W-coated CFC tiles which impose stricter heat load restrictions .
# To reduce the frequency of false positive alarms from the thermal protection system , recent efforts have been invested in the characterisation of appearance , and cataloguing hotspots in the field of view of the protection cameras [ 11 ] .
# As mentioned above , the activity of the hot spots is caused by plasma-wall interaction , i.e . a hot spot becomes active when there is sufficient heat flux from the plasma towards the plasma-facing surface .
# Thus , in each pulse we observe : • good time : total time in which the outer strike point was within the defined activation area , and the NBI heating power was above the minimum value , • hot time : the total time of hot spot activity within the good time intervals The combined good and hot times are shown for the hot spots on tiles 6 and 7 , detected at threshold value of 250 are shown in Fig . 10 a and 10b respectively .
# The difference in the good time was also visibly reflected in the stretch between JPNs 87000 and 87200 .
# Beyond that , the analysis of the activity of the hot spots during a running campaign can be used to help to identify potential hot spots before they evolve to the point of prematurely terminating pulses by causing high temperature alarms , while the identified plasma parameter values can serve as input data for shaping future discharges to avoid further degradation of the divertor surfaces .
# Defining the activation areas and minimum required NBI power for the activity of the hot spots makes it possible to distinguish whether the observed gradual increase in the hot spot activity was caused by gradually increasing powers deposited on unchanging plasma facing components , or was in indeed caused by changes on the surface .
# The activity of the first group roughly followed the trends of the good time , while the second group , by definition , did not show any activity prior to JPN 86,000 .
# With the lower threshold value , the hot time trends were found to follow the good trends more closely , however the main features of the results remain unchanged , i.e . the strike point had been in the collection area of the second group with the same frequency as for the first group , well before the second group showed any activity , and the significant increase in the activity of the second group in the range of pulses between JPN 87000 and 87200 .
#
#
# Correlation of surface chemical states with hydrogen isotope retention in divertor tiles of JET with ITER-Like Wall
# 10.1016/j.fusengdes.2018.04.124
# Therefore , the fuel retention behavior for these wall materials will give the important information for reactor safety .
# In addition , no large H retention was seen supporting this hypothesis .
# The origin for this H release at high temperatures is still unknown , and further analyses are required .
#
#
# An improved model for the accurate calculation of parallel heat fluxes at the JET bulk tungsten outer divertor
# 10.1088/1741-4326/aad83e
# These conclusions , along with the improvement in the predictability of the divertor thermal behaviour , are critical for JET future DT operations , and are also directly applicable to the design of the ITER divertor monoblocks .
#
#
# Identification of BeO and BeOxDy in melted zones of the JET Be limiter tiles: Raman study using comparison with laboratory samples
# 10.1016/j.nme.2018.11.008
# Note that hydrogenated amorphous carbon can also give rise to a linear background with a positive slope [ 30 ] ( and references therein ) .
# This confirms that the formation of deuteroxides is probably an efficient way of trapping D. Note that it can also affect droplet formation and composition .
# Stamp D. Borodin J.P. Coad A.G. Carrasco A. Kirschner S. Krat K. Krieger B. Lipschultz C. Linsmeier G.F. Matthews K. Schmid J.E.T .
# However , the phase diagram of such material is still lacking .
# There is a good agreement between the bands displayed in Fig . 2a for the JET samples ( Type 1 and Type 2 ) and for these NIST data .
#
#
# Determination of tungsten sources in the JET-ILW divertor by spectroscopic imaging in the presence of a strong plasma continuum
# 10.1016/j.nme.2018.12.009
# Keywords Tungsten erosion Tungsten imaging spectroscopy W Divertor JET-ILW PSI PFC 1 Introduction Tungsten ( W ) is foreseen as the main plasma-facing material ( PFM ) in fusion devices , such as ITER with full-tungsten divertor [ 1,2 ] , because of its excellent material properties − a high threshold energy for sputtering [ 3 ] , a high melting point [ 4 ] and a low tritium inventory [ 5,6 ] .
# The result achieved from the experiment in the corner configuration Fig . 3c ) demonstrates the effective application of this method for the evaluation of the W erosion even in the inner divertor region where the strong recombination emission is dominating over the tungsten emission .
# Taking into the account the parasitic light compensation could further improve the measurements in the inner divertor .
# The results achieved from the experiment in the corner configuration ( Fig . 3c ) demonstrate the effective application of this method for the evaluation of the W erosion even in the inner divertor region where the strong recombination emission is dominating over the tungsten emission .
# Obviously , the time resolution of the recording camera systems of 30.5 ms was insufficient to resolve the ELMs .
#
#
# Thermal desorption spectrometry of beryllium plasma facing tiles exposed in the JET tokamak
# 10.1016/j.fusengdes.2018.05.075
# Keywords Thermal desorption spectrometry Beryllium Plasma facing component Fuel retention JET Tritium 1 Introduction Quantification of hydrogen ( H ) and its isotopes deuterium ( D ) and tritium ( T ) in plasma facing components ( PFC ) of nuclear fusion devices , and assessment of trap site interactions with H atoms , are important from both the fundamental and technological point of view .
# The MRF provides test facilities for work on active materials that can not be accommodated at universities because their activity levels are too high , but are not sufficiently active to require a full nuclear licenced site for analysis .
# Since only the heating stage is annealed , and the rest of the chamber is at RT ( and potentially acting as a cold sink for desorbed species ) , the line-of-sight method improves the detection by collecting efficiently the gaseous elements .
# Although the ever-present question of what emissivity to use for unknown material surfaces and how the emissivity changes at elevated temperatures remains , some good progress is being made as a part of the current TDS development making use of extensive expertise in camera calibration of the JET in-vessel protection system [ 14 ] and will be published at a later stage .
# It has been shown previously , that keV-range D implantation in W creates a number of implantation-induced defects , which act as deep trapping sites for D [ 15 ] making the samples suitable for reference use .
# Consequently a valuable A valuable conclusion for our work using TDS system is that the method for quantifying D by comparison of results from a sample of known D content is acceptable .
# All these methods have limitations in estimating the total long-term fuel retention .
# The maximum activity of a research room is currently limited to 3.75 GBq ( 60Co ) .
# The difference between these three independent temperature measurements of the same sample at the heating rate of 10 K/min were ±25 K , and thus show a good agreement .
# T present in DT ( mass 5 ) accounts for ∼20–30 % of the total T and is mostly released in the range ∼600–850 K. Currently , it is not possible to distinguish HT from D2 , hence the contribution of HT in mass 4 remains unsolved .
#
#
# Comparison of the structure of the plasma-facing surface and tritium accumulation in beryllium tiles from JET ILW campaigns 2011-2012 and
# 10.1016/j.nme.2019.02.011
# Beryllium choice is based on its low Z , good thermal conductivity , and high oxygen gettering characteristics .
# ( 1 ) 1 2 H ( D ) + 1 2 H ( D ) → 1 3 H ( T ) + 1 1 H ( H ) + 4.03 M e V Third source of tritium in beryllium that will play significant role in the future fusion devices is neutron induced transmutation of beryllium .
# However , it must be emphasized that overall neutron yield in ILW1 and ILW2 are very low ( ∼5·1019 neutrons in total ) and the dominant source of tritium can be considered previous D – T experiments .
# To predict tritium accumulation patterns in ITER and other future fusion devices tritium - deuterium plasma experiments are crucial as fuel accumulation highly depents of the way how it is introduced in the vacuum vessel .
# First mirror test in JET for ITER: Complete overview after three ILW campaigns
# 10.1016/j.nme.2019.02.009
# Therefore , their performance is crucial for reliable plasma diagnosis and safe operation .
# This method gives good depth resolution of a few nm by excellent mass separation [ 17 ] .
# There is a slight relative decrease ( 2–3 % ) in near infrared only for the mirror from the cassette entrance ( 0.0 cm ) , while there is even relative improvement by 2–10 % in the ultra violet and a slight positive trend is in the visible range ( < 900 nm ) on other mirrors .
# One may assume that this is a potential source of tungsten on the main chamber mirrors .
# Truly speaking it is even difficult to find a proper set of techniques to determine conclusively morphology of this very small “ needles ” .
# One may very tentatively suggest that they were formed as result of arcing ( parasitic discharge ) between the mirror and the protecting structure ( tube or baffle ) , but there is no chance to prove it .
# This would help elimination of possible negative factors which may influence the surface state of mirrors .
# In parallel , efforts should also be dedicated to the design/development of mirror replacement method .
#
#
# Silicon foil solar cells on low cost supports
# 10.1063/1.5012744
# Indeed , the use of silicon foils for the production of solar cells offers the ability to reduce material costs while allowing potentially a higher conversion efficiency .
# In view of potential industrialization , mechanical support must be used during solar cells and module fabrication to avoid silicon foil breakage .
#
#
# Evaluating the Operational Potential of LRV Signatures Derived from UAV Imagery in Performance Evaluation of Cool Roofs
# 10.3390/en12142787
# It is quite difficult to find studies regarding area-wide data from UAV ( Unmanned Aerial Vehicle ) remote sensing in evaluating the energy saving performance of a cool roof .
